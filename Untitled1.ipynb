# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
main_df = pd.read_csv('FooddeliveryApp Analysis Dataset.csv')
main_df.shape
# Out:
# (6000, 20)

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customer_id      6000 non-null   object
#  1   gender           6000 non-null   object
#  2   age              6000 non-null   object
#  3   city             6000 non-null   object
#  4   signup_date      6000 non-null   object
#  5   order_id         6000 non-null   object
#  6   order_date       6000 non-null   object
#  7   restaurant_name  6000 non-null   object
#  8   dish_name        6000 non-null   object
#  9   category         6000 non-null   object
#  10  quantity         6000 non-null   int64
#  11  price            6000 non-null   float64
#  12  payment_method   6000 non-null   object
#  13  order_frequency  6000 non-null   int64
#  14  last_order_date  6000 non-null   object
#  15  loyalty_points   6000 non-null   int64
# ...

# %%
main_df["order_date"] = pd.to_datetime(main_df["order_date"], format="%m/%d/%Y", errors="coerce")
main_df["order_month"] = main_df["order_date"].dt.month

# %%
main_df.drop(columns=["customer_id","signup_date","order_id","order_date","last_order_date","rating_date"],inplace=True)
main_df.shape
# Out:
# (6000, 15)

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   gender           6000 non-null   object
#  1   age              6000 non-null   object
#  2   city             6000 non-null   object
#  3   restaurant_name  6000 non-null   object
#  4   dish_name        6000 non-null   object
#  5   category         6000 non-null   object
#  6   quantity         6000 non-null   int64
#  7   price            6000 non-null   float64
#  8   payment_method   6000 non-null   object
#  9   order_frequency  6000 non-null   int64
#  10  loyalty_points   6000 non-null   int64
#  11  churned          6000 non-null   object
#  12  rating           6000 non-null   int64
#  13  delivery_status  6000 non-null   object
#  14  order_month      6000 non-null   int32
# dtypes: float64(1), int32(1), int64(4), object(9)
# memory usage: 679.8+ KB

# %%
main_df.nunique()
# Out:
# gender                3
# age                   3
# city                  5
# restaurant_name       5
# dish_name             5
# category              5
# quantity              5
# price              5872
# payment_method        3
# order_frequency      50
# loyalty_points      501
# churned               2
# rating                5
# delivery_status       3
# order_month          12
# dtype: int64

# %%
main_df_encoded = pd.get_dummies(main_df, drop_first=True)
main_df_encoded = main_df_encoded.astype({col: int for col in main_df_encoded.select_dtypes('bool').columns})
main_df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   quantity                    6000 non-null   int64
#  1   price                       6000 non-null   float64
#  2   order_frequency             6000 non-null   int64
#  3   loyalty_points              6000 non-null   int64
#  4   rating                      6000 non-null   int64
#  5   order_month                 6000 non-null   int32
#  6   gender_Male                 6000 non-null   int64
#  7   gender_Other                6000 non-null   int64
#  8   age_Senior                  6000 non-null   int64
#  9   age_Teenager                6000 non-null   int64
#  10  city_Karachi                6000 non-null   int64
#  11  city_Lahore                 6000 non-null   int64
#  12  city_Multan                 6000 non-null   int64
# ...

# %%
main_df_encoded = main_df_encoded.drop(columns=["order_frequency","loyalty_points"])

# %%
corr_with_churn = main_df_encoded.corr(numeric_only=True)["churned_Inactive"]
corr_df = corr_with_churn.to_frame().reset_index()
corr_df.columns = ["Feature", "Correlation_with_churned_Inactive"]
corr_df = corr_df.reindex(corr_df["Correlation_with_churned_Inactive"].abs().sort_values(ascending=False).index)
print(corr_df)
# Out:
#                        Feature  Correlation_with_churned_Inactive
# 26            churned_Inactive                           1.000000
# 13  restaurant_name_McDonald's                          -0.027570
# 16             dish_name_Fries                           0.026296
# 3                  order_month                           0.023746
# 6                   age_Senior                           0.023623
# 19          dish_name_Sandwich                          -0.022360
# 9                  city_Lahore                           0.021342
# 23            category_Italian                           0.020849
# 10                 city_Multan                           0.019131
# 11               city_Peshawar                          -0.018624
# 8                 city_Karachi                          -0.018193
# 2                       rating                           0.017177
# 14   restaurant_name_Pizza Hut                           0.015935
# ...

# %%
y = main_df_encoded["churned_Inactive"]
X = main_df_encoded[["restaurant_name_McDonald's","dish_name_Fries"]]

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.52
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.51      0.85      0.64       603
#            1       0.55      0.19      0.28       597
#
#     accuracy                           0.52      1200
#    macro avg       0.53      0.52      0.46      1200
# weighted avg       0.53      0.52      0.46      1200
#
#
# Confusion Matrix:
#  [[512  91]
#  [485 112]]

# %%
import statsmodels.api as sm
X_const = sm.add_constant(X)
logit_model = sm.Logit(y, X_const)
result = logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.692415
#          Iterations 3
#                            Logit Regression Results
# ...
# Dep. Variable:       churned_Inactive   No. Observations:                 6000
# Model:                          Logit   Df Residuals:                     5997
# Method:                           MLE   Df Model:                            2
# Date:                Tue, 02 Dec 2025   Pseudo R-squ.:                0.001036
# Time:                        23:11:44   Log-Likelihood:                -4154.5
# converged:                       True   LL-Null:                       -4158.8
# Covariance Type:            nonrobust   LLR p-value:                   0.01348
# ...
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

X_vif = sm.add_constant(X)
vif_data = pd.DataFrame()
vif_data["Feature"] = X_vif.columns
vif_data["VIF"] = [variance_inflation_factor(X_vif.values, i)
                   for i in range(X_vif.shape[1])]

print(vif_data)
# Out:
#                       Feature       VIF
# 0                       const  1.478154
# 1  restaurant_name_McDonald's  1.000143
# 2             dish_name_Fries  1.000143

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 5))
plt.imshow(cm, interpolation='nearest')
plt.title("Confusion Matrix")
plt.colorbar()

classes = ["Pred 0", "Pred 1"]
plt.xticks(np.arange(len(classes)), classes)
plt.yticks(np.arange(len(classes)), ["Actual 0", "Actual 1"])

for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(j, i, cm[i, j], ha="center", va="center", color="white", fontsize=14)

plt.xlabel("Predicted Label")
plt.ylabel("Actual Label")
plt.tight_layout()
plt.show()

# %% [markdown]
# Random Forest

# %%
main_df_encoded.columns
# Out:
# Index(['quantity', 'price', 'rating', 'order_month', 'gender_Male',
#        'gender_Other', 'age_Senior', 'age_Teenager', 'city_Karachi',
#        'city_Lahore', 'city_Multan', 'city_Peshawar', 'restaurant_name_KFC',
#        'restaurant_name_McDonald's', 'restaurant_name_Pizza Hut',
#        'restaurant_name_Subway', 'dish_name_Fries', 'dish_name_Pasta',
#        'dish_name_Pizza', 'dish_name_Sandwich', 'category_Continental',
#        'category_Dessert', 'category_Fast Food', 'category_Italian',
#        'payment_method_Cash', 'payment_method_Wallet', 'churned_Inactive',
#        'delivery_status_Delayed', 'delivery_status_Delivered'],
#       dtype='object')

# %%
y = main_df_encoded["churned_Inactive"]
X = main_df_encoded.drop(columns=["churned_Inactive"])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

rf = RandomForestClassifier(random_state=42)
param_grid = {
    "n_estimators": [50, 100, 150, 200],
    "max_depth": [5, 10, 15],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4]
}
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid,cv=3,scoring="accuracy",n_jobs=-1,verbose=2)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 108 candidates, totalling 324 fits
# GridSearchCV(cv=3, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [5, 10, 15],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 150, 200]},
#              scoring='accuracy', verbose=2)

# %%
print("\nBest Parameters:", grid_search.best_params_)
print("Best Accuracy Score:", grid_search.best_score_)
# Out:
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 150}
# Best Accuracy Score: 0.518125

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)
print("\nTest Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Test Accuracy: 0.49833333333333335

# %%
importances = best_model.feature_importances_
indices = np.argsort(importances)[::-1]

plt.figure(figsize=(8, 2))
plt.bar(range(len(importances)), importances[indices])
plt.xticks(range(len(importances)), X.columns[indices], rotation=90)
plt.title("Feature Importance")
plt.show()

# %%
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.52      0.51       603
#            1       0.50      0.48      0.49       597
#
#     accuracy                           0.50      1200
#    macro avg       0.50      0.50      0.50      1200
# weighted avg       0.50      0.50      0.50      1200
#
#
# Confusion Matrix:
#  [[313 290]
#  [312 285]]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 5))
plt.imshow(cm, interpolation='nearest')
plt.title("Confusion Matrix")
plt.colorbar()

classes = ["Pred 0", "Pred 1"]
plt.xticks(np.arange(len(classes)), classes)
plt.yticks(np.arange(len(classes)), ["Actual 0", "Actual 1"])

for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(j, i, cm[i, j], ha="center", va="center", color="white", fontsize=14)

plt.xlabel("Predicted Label")
plt.ylabel("Actual Label")
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score

y_prob = best_model.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
auc_score = roc_auc_score(y_test, y_prob)

plt.figure(figsize=(7, 6))
plt.plot(fpr, tpr, label=f"Random Forest (AUC = {auc_score:.3f})")
plt.plot([0, 1], [0, 1], linestyle="--")  
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.grid(True)
plt.show()

# %%
import joblib

joblib.dump(model, "logistic_model.pkl")       
joblib.dump(best_model, "random_forest.pkl")
# Out:
# ['random_forest.pkl']

# %%
feature_names = X.columns.tolist()
joblib.dump(feature_names, "feature_names.pkl")
# Out:
# ['feature_names.pkl']
